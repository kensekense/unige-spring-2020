# %%
import numpy as np

# %%
original = []
transliterated = []

with open("", "r") as fp:
    for i,line in enumerate(fp):
        if i%2 == 0:
            original.append(line)
        else:
            transliterated.append(line)

# %%
parallel = []
for i,j in zip(original,transliterated):
    words_i = i.split()
    words_j = j.split()
    
    for wordi, wordj in zip(words_i,words_j):
        parallel.append((wordi, wordj))

# %%
for item in set(parallel):
    print(item[0],item[1])
# Out:
# heads heds
# also alsoe
# Assassination usasinaeshun
# continued kawntinued
# ( (
# ranks ranks
# drawing jrauyeeng
# as as
# Anarchists anarkists
# change chainj
# had had
# propaganda propaganda
# Errico erikoe
# capitalism kapituulizm
# movement moovment
# philosophies filausuufeez
# has haz
# Catholicism kathaulisizm
# methods methids
# took tuk
# seeing seeng
# illustrating ilustrateeng
# reaction reeakshun
# higher hyur
# centralized senchruulizd
# early urlee
# theorists theerists
# oppressive uupresiv
# there ther
# capitalist kapituulist
# these thees
# making maikeeng
# established established
# fundamentalist fundamentalist
# government guvurment
# ago agoe
# prioritizes pryoerityzes
# a a
# Various vereeuus
# categorization kateguryzaishun
# saw saw
# Not not
# supremacy soopremusee
# Spain spain
# principles prinsipuls
# contemporary kuntemporaree
# limited limited
# promote proemoet
# been bin
# possible posibul
# era era
# times tyms
# socialism soshuulizm
# vision vishun
# state stait
# between bitween
# slavery slaivuree
# more moor
# was waz
# should shuld
# disparate disperet
# anarchism anarkizuum
# group groop
# overlap oevurlap
# or or
# - -
# were wur
# revolutions revulooshuns
# violence violens
# ; ;
# have hav
# autocratic autoekratik
# advocate advoekaet
# as az
# As as
# commentators kumentaiturs
# right ryt
# oppose uupoez
# Roman roemen
# example ekzampul
# some sum
# ' '
# systems sistems
# authority authoeritee
# attitude atitood
# are are
# though tho
# While whiel
# did did
# means meens
# attempts etemps
# , ,
# committed kumited
# the the
# through throo
# point point
# that that
# activists aktivists
# within within
# violence vylens
# representative reprisentativ
# Anarchism anarkizuum
# state staet
# today toodai
# against agenst
# ends ends
# tendency tendensee
# perplexing purplekseeng
# This this
# Malatesta malastesta
# tradition chruudishuun
# equality ikoowalitee
# focused foekusd
# generate jenurait
# hierarchical hyrarikikuul
# first furst
# shared sherd
# Bolshevism boelshevizm
# approach uuproech
# serve surv
# ) )
# various vereeuus
# result reesult
# but but
# priority pryoritee
# controversial kuntruvurshul
# employed emploid
# any enee
# tendencies tendensees
# proponents propoenents
# major maijur
# combining kumbyneeng
# relatively relativly
# religions rilijuns
# direct dyrekt
# violence vilens
# They thae
# multiple multipul
# between beetween
# can kan
# rather rathur
# create kreeait
# two too
# on on
# by by
# deed deed
# carried kareed
# currents kurents
# states staets
# use yoos
# coercive koersiv
# to to
# However houevur
# part part
# terrorism teroerizm
# perspectives purspektivs
# sources sorses
# made maid
# one wun
# which which
# . .
# e.g e.g
# feudalism fiyoodalizm
# while whiel
# evil eevil
# at at
# 20th 20th
# active aktiv
# reformist riformist
# difficult difikult
# following faloeeeng
# sabotage saboetaj
# reflect reflekt
# Evolutionary evulooshuneree
# groups groops
# generally jenuralee
# last last
# anti entee
# classical klasikul
# who hoo
# syndicalism sindikalizm
# syncretic sinkretik
# of ov
# core koor
# unity yoonitee
# broad braud
# strikes stryks
# necessary neseseree
# common kaumen
# namely naimly
# them them
# For foer
# towards toewurds
# many menee
# classical klaseekuu
# all uul
# out aut
# the th
# constellations kunstulaeshuns
# than than
# during dureeng
# use yuz
# anarchists anarkists
# other othur
# acts aks
# it it
# broader braudur
# approaches uuproeches
# antipathetic anteeputhetik
# they thae
# gender jendur
# heterosexism heteroeseksizm
# describe diskryb
# array urae
# quite kwyt
# thought thaut
# although althoe
# century senchuuree
# upon uupaun
# imperialism impeereeuulizm
# Tactics taktiks
# evolutionary evulooshuneree
# forms foerms
# overthrow uuvurthroe
# eclectic uuklektik
# Establishment establishment
# gradual gradooul
# schools skools
# " "
# militancy militensee
# white whyt
# Goldman goeldman
# On on
# etc etc
# hand hand
# goals goels
# general jenural
# confront kunfrunt
# Classical klasikul
# action akshun
# Islam izlam
# second sekend
# no no
# is is
# successful suksesful
# revolutionary revulooshuneree
# believed buleevd
# those thoz
# aims aims
# Anarchist anarkist
# militant militent
# there theer
# differently difrently
# tended tendid
# remained reemaind
# class klas
# prominent prominent
# argued argued
# armed armd
# Ukraine yookrain
# forces foerses
# disagree disugree
# new nue
# merely meerlee
# A a
# tactic taktik
# institutions institooshuns
# stable staebuul
# anarcho anarkoe
# opposed uupoezd
# patriarchy paitreearky
# its its
# monarchy moenarkee
# reject rejekt
# During dureeng
# only oenlee
# pacifists pasifists
# course koors
# tyrant tyrent
# movements moovments
# philosophical filausuufeekuu
# principle prinsipul
# and and
# each eech
# be bee
# oppression uupreshun
# ethics ethiks
# role roel
# sought sawt
# shifted shiftid
# Emma ema
# prominent praumeenent
# communists kaumuenists
# every evree
# an an
# always ulwaes
# economic ekunaumik
# formal foermul
# destroy disjroi
# consensus kunsensuus
# anarchisms anarkizuums
# tactics taktiks
# The th
# concepts kunseps
# singular singuelur
# democracy dimaukrasee
# while whyl
# anarcha anarka
# take taik
# exist egzist
# even eevin
# in in
# significant signifikant
# society sosyetee
# include inklood
# anarchist anarkist
# feminists feminists
# society soesyetee
