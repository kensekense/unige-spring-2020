# %% [markdown]
# # Computational Finance
# ## Series 6
# Tientso Ning

# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt

# %%
#read data
data = pd.read_table("./data.dat", header=None, names=["timestamp", "bid", "ask"])
data["timestamp"] = data["timestamp"].apply(lambda x : time.strftime("%Y-%m-%d %H:%M:%S", time.gmtime(x)))

#trim data
data = data.head(np.around(len(data)*0.3).astype(int))

#pre-processing removal
data = data[data["timestamp"] > "2012-01-01 00:00:00"]

#process data
data.timestamp = pd.DatetimeIndex(data.timestamp)
data.set_index('timestamp', inplace=True)

# %%
#15 minute intervals
data = data.resample('15min').mean()

# %%
#TWAP is just the values we have at each 15 minute interval
data['TWAP'] = data['bid']

#VWAP calculations
data['volume'] = data.index.value_counts()
data['cumulative.volume'] = data['volume'].cumsum()
data['tp.v'] = data['bid']*data['volume']
data['cumulative.tp.v'] = data['tp.v'].cumsum()
data['VWAP'] = data['cumulative.tp.v']/data['cumulative.volume']

# %%
#sample 20 different time blocks
for i in range(20):
    x = np.random.randint(0,len(data))
    print(data[x:x+12][['TWAP','VWAP']])
    
    print("---")
    
    twap_price = np.sum(data[x:x+12][['TWAP']]*1000000)[0]
    twap_dec_price = (data.iloc[x][['TWAP']]*12000000)[0]
    print("TWAP Price: ", twap_price)
    print("Decision Price: ", twap_dec_price) 
    print("Difference: ", twap_price-twap_dec_price)
    
    print("---")
    
    vwap_price = np.sum(data[x:x+12][['VWAP']]*1000000)[0]
    vwap_dec_price = (data.iloc[x][['VWAP']]*12000000)[0]
    print("VWAP Price: ", vwap_price)
    print("TWAP - VWAP: ", twap_price-vwap_price)
    
    print("===")
# Out:
#                          TWAP      VWAP
# timestamp
# 2012-01-18 18:15:00  1.284291  1.008762
# 2012-01-18 18:30:00  1.284734  1.008930
# 2012-01-18 18:45:00  1.284281  1.009098
# 2012-01-18 19:00:00  1.284291  1.009265
# 2012-01-18 19:15:00  1.284929  1.009433
# 2012-01-18 19:30:00  1.284822  1.009601
# 2012-01-18 19:45:00  1.285402  1.009768
# 2012-01-18 20:00:00  1.285643  1.009936
# 2012-01-18 20:15:00  1.285839  1.010103
# 2012-01-18 20:30:00  1.285831  1.010271
# 2012-01-18 20:45:00  1.286156  1.010438
# 2012-01-18 21:00:00  1.285702  1.010605
# ---
# TWAP Price:  15421921.530048873
# Decision Price:  15411495.51020407
# Difference:  10426.01984480396
# ---
# VWAP Price:  12116208.49425893
# TWAP - VWAP:  3305713.0357899424
# ===
#                          TWAP      VWAP
# timestamp
# 2012-01-03 03:45:00  1.297727  1.293944
# 2012-01-03 04:00:00  1.298107  1.293973
# 2012-01-03 04:15:00  1.298304  1.294004
# 2012-01-03 04:30:00  1.298108  1.294032
# 2012-01-03 04:45:00  1.297649  1.294057
# 2012-01-03 05:00:00  1.297985  1.294084
# 2012-01-03 05:15:00  1.298110  1.294111
# 2012-01-03 05:30:00  1.298778  1.294143
# 2012-01-03 05:45:00  1.298705  1.294174
# 2012-01-03 06:00:00  1.299187  1.294207
# 2012-01-03 06:15:00  1.299948  1.294245
# 2012-01-03 06:30:00  1.299726  1.294281
# ---
# TWAP Price:  15582335.526668679
# Decision Price:  15572725.71428571
# Difference:  9609.812382968143
# ---
# VWAP Price:  15529255.663933795
# TWAP - VWAP:  53079.862734884024
# ===
#                          TWAP      VWAP
# timestamp
# 2012-01
# 2012-01-11 14:30:00  1.268441  1.049146
# 2012-01-11 14:45:00  1.269061  1.049377
# 2012-01-11 15:00:00  1.268378  1.049606
# 2012-01-11 15:15:00  1.267655  1.049835
# 2012-01-11 15:30:00  1.267665  1.050062
# 2012-01-11 15:45:00  1.268541  1.050291
# 2012-01-11 16:00:00  1.268567  1.050519
# 2012-01-11 16:15:00  1.268666  1.050746
# 2012-01-11 16:30:00  1.268733  1.050973
# ---
# TWAP Price:  15220900.18842506
# Decision Price:  15233200.355699265
# Difference:  -12300.167274205014
# ---
# VWAP Price:  12596607.36801549
# TWAP - VWAP:  2624292.82040957
# ===
#                      TWAP  VWAP
# timestamp
# 2012-01-06 22:15:00   NaN   NaN
# 2012-01-06 22:30:00   NaN   NaN
# 2012-01-06 22:45:00   NaN   NaN
# 2012-01-06 23:00:00   NaN   NaN
# 2012-01-06 23:15:00   NaN   NaN
# 2012-01-06 23:30:00   NaN   NaN
# 2012-01-06 23:45:00   NaN   NaN
# 2012-01-07 00:00:00   NaN   NaN
# 2012-01-07 00:15:00   NaN   NaN
# 2012-01-07 00:30:00   NaN   NaN
# 2012-01-07 00:45:00   NaN   NaN
# 2012-01-07 01:00:00   NaN   NaN
# ---
# TWAP Price:  0.0
# Decision Price:  nan
# Difference:  nan
# ---
# VWAP Price:  0.0
# TWAP - VWAP:  0.0
# ===

# %% [markdown]
# Here, we can see that for the most part, TWAP trading algorithm performs better than the decision price if made in one purchase at time `t`. However, VWAP prices are overall better than TWAP prices.

# %% [markdown]
# ### Algorithm Based on Price Evolution

# %%
#artificial time series
np.random.seed(1)
x = 10 + np.cumsum(0.5-np.random.random(1000))

# %%
#visualize the time series
plt.plot(x)
plt.xlabel("time")
plt.ylabel("value")
plt.title("Artificial Times Series")
# Out:
# Text(0.5, 1.0, 'Artificial Times Series')

# %%
def CDC (ts, delta):
    
    L = len(ts)
    direction = -1
    x = 0
    dc = 1
    pos = []
    neg = []
    
    for i in range (1, L): #cycle through the ts
        
        if np.abs(ts[x]-ts[i]) > delta*ts[x]: #scaling law
            
            #calculate directional change/overshoot
            if np.sign(ts[x]-ts[i]) != np.sign(direction):
                direction = direction * -1 #change direction
                dc += 1
                if np.sign(ts[x]-ts[i]) == 1:
                    pos.append(ts[i])
                else:
                    neg.append(ts[i])
            
            else:
                #overshoot
                pos.append(np.nan)
                neg.append(np.nan)
                
            x = i #set ne
            
        
        
    return dc, pos, neg

# %%
num_dc, dc_pos, dc_neg = CDC(x, 0.01)
plt.plot(x, label="x")
plt.plot(dc_pos, marker="o", label="pos")
plt.plot(dc_neg, marker="x", label="neg")
plt.legend()
plt.show()

# %%
dc_pos
# Out:
# [9.862653501855268,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.149918865372133,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.211028982870863,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.389565757546334,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.632044589225018,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.989528734168896,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.934170184200319,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.904205267589372,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.696071755968848,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.646275105231343,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.462470361568569,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.485309187646152,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.134945334542055,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  9.98055066048514,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.022963191099645,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.123216080793279,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.084700488849123,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.204688391909663,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.338506148119832,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  10.063450524433975,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  9.740594325512113,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  9.697575494241795,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  9.656480675843882,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  9.47634454106077,
#  nan,
#  nan,
#  nan,
#  nan,
#  9.495845017418919,
#  nan,
#  nan,
#  nan,
#  nan,
#  9.395400544094853,
#  nan,
#  nan]
